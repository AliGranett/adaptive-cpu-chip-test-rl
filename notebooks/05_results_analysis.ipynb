# %% [markdown]
# # 05 - Results Analysis
#
# Compare every method (Always Continue, Random, Rule-Based, Logistic Regression, XGBoost, Q-Learning, DQN) on the held-out test set and display the saved figures. Run notebook 04 first so trained RL models exist (otherwise they are trained on the fly).

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'src').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.config import CONFIG
from src.evaluation.comparison import run_default_comparison

table, metrics = run_default_comparison(CONFIG, quick=True)
table

# %%
from IPython.display import Image, display
for fig in ['cost_savings_comparison.png', 'precision_recall_comparison.png']:
    path = CONFIG.paths.figures / fig
    if path.exists():
        display(Image(filename=str(path)))

# %%
# Confusion matrices for the RL agents.
for name in ['q-learning', 'dqn']:
    path = CONFIG.paths.figures / f'confusion_{name}.png'
    if path.exists():
        display(Image(filename=str(path)))
